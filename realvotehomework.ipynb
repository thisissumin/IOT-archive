# %% [markdown]
# <a href="https://colab.research.google.com/github/thisissumin/IOT-archive/blob/main/realvotehomework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = 'http://apis.data.go.kr/9760000/PofelcddInfoInqireService/getPoelpcddRegistSttusInfoInqire'
params ={'serviceKey' : 'qIMC/9LSNp9dyMB3Mwq2NF4S6mGqATBx/ed9LlF0DotbkjpZBhGxyweP7DyQaHsk/qiMwj5/FcQN6mMJboYO+Q==', 'pageNo' : '1', 'numOfRows' : '10', 'sgId' : '20240410', 'sgTypecode' : '2', 'sggName' : '', 'sdName' : '' }

r = requests.get(url, params=params)
print(r.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?><response>\n<header>\n<resultCode>INFO-00</resultCode>\n<resultMsg>NORMAL SERVICE</resultMsg>\n</header>\n<body>\n<items>\n  <item>\n    <num>1</num>\n    <sgId>20240410</sgId>\n    <sgTypecode>2</sgTypecode>\n    <huboid>100151444</huboid>\n    <sggName>\xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac</sggName>\n    <sdName>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c</sdName>\n    <wiwName>\xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac</wiwName>\n    <jdName>\xeb\x8d\x94\xeb\xb6\x88\xec\x96\xb4\xeb\xaf\xbc\xec\xa3\xbc\xeb\x8b\xb9</jdName>\n    <name>\xea\xb3\xbd\xec\x83\x81\xec\x96\xb8</name>\n    <hanjaName>\xe9\x83\xad\xe7\x9b\xb8\xe5\xbd\xa6</hanjaName>\n    <gender>\xeb\x82\xa8</gender>\n    <birthday>19711118</birthday>\n    <age>52</age>\n    <addr>\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac \xed\x86\xb5\xec\x9d\xbc\xeb\xa1\x9c</addr>\n    <jobId>85</jobId>\n    <job>\xeb\xb3\x80\xed\x98\x
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, features="xml")

# %%
soup.find_all('name')
# Out:
# [<name>곽상언</name>,
#  <name>이종걸</name>,
#  <name>전현희</name>,
#  <name>임연희</name>,
#  <name>손석기</name>,
#  <name>최재형</name>,
#  <name>금태섭</name>,
#  <name>최윤호</name>,
#  <name>한규창</name>,
#  <name>한상현</name>]

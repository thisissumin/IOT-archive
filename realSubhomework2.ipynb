# %% [markdown]
# <a href="https://colab.research.google.com/github/thisissumin/IOT-archive/blob/main/realSubhomework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  url='https://api.thingspeak.com/update?api_key=DWJQO3S9WPJ39CET'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1501")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"10,13","co2":"399","bme680":"25.92,31.45,891318,100820,42.21","time":"2024-04-04 20:13:31", "serial":17267, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"9,12","co2":"399","bme680":"25.92,31.46,894281,100820,42.13","time":"2024-04-04 20:13:32", "serial":17268, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"10,13","co2":"399","bme680":"25.92,31.48,893094,100819,42.21","time":"2024-04-04 20:13:33", "serial":17269, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"11,14","co2":"399","bme680":"25.92,31.45,899064,100820,42.21","time":"2024-04-04 20:13:34", "serial":17270, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"12,16","co2":"399","bme680":"25.92,31.47,891909,100819,42.21","time":"2024-04-04 20:13:35", "serial":17271, "ip":"203.255.190.49"}
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/thisissumin/IOT-archive/blob/main/realSubhomework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"11,11","co2":"399","bme680":"25.94,31.45,894281,100813,42.71","time":"2024-04-04 20:10:59", "serial":17115, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"13,15","co2":"559","bme680":"27.37,28.71,1538461,100861,38.70","time":"2024-04-04 20:10:59", "serial":12555, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"12,14","co2":"394","bme680":"26.64,30.58,702257,100819,42.13","time":"2024-04-04 20:11:00", "serial":12564, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"11,11","co2":"399","bme680":"25.94,31.46,895472,100813,42.71","time":"2024-04-04 20:11:00", "serial":17116, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"12,14","co2":"559","bme680":"27.37,28.72,1531375,100861,38.70","time":"2024-04-04 20:11:00", "serial":12556, "ip":"203.255.190.49"}
# ...
